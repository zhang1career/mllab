# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split, DataLoader, Dataset, TensorDataset

# %%
"""
dataset
"""

# data loading
dataFile = pd.read_excel(r'iris_dataset.xlsx')
print('Take a look at sample from the dataset:')
print(dataFile.head())

# data balance verifing
print('\n')
print('Our dataset is balanced and has the following values to predict:')
print(dataFile['Iris_Type'].value_counts())

# data washing
labels = {'Iris-setosa':0, 'Iris-virginica':1, 'Iris-versicolor':2}
dataFile['IrisType_num'] = dataFile['Iris_Type']  # create a new column
dataFile.IrisType_num = [labels[item] for item in dataFile.IrisType_num]

# define input and output
print('\n')
input = dataFile.iloc[:, 1:-2]  # drop the 1st column and the last two
print('Input values are:')
print(input.head())
print('\n')
output = dataFile.loc[:, 'IrisType_num']  # output the last column
print('Output value is:')
print(output.head())

# convert input and output to tensors
print('\n')
input = torch.tensor(input.to_numpy()).float()  # create tensor type torch.float32
print('Input format: ', input.shape, input.dtype)
output = torch.tensor(output.to_numpy())        # create tensor type torch.int64
print('Output format: ', output.shape, output.dtype)
data = TensorDataset(input, output)

# split into train, verify and test
number_rows = len(input)
test_split = int(number_rows * 0.3)
verify_split = int(number_rows * 0.2)
train_split = number_rows - test_split - verify_split
train_set, verify_set, test_set = random_split(data, [train_split, verify_split, test_split])

# create DataLoader
train_batch_size = 10
train_loader = DataLoader(train_set, batch_size=train_batch_size, shuffle=True)
verify_loader = DataLoader(verify_set, batch_size=1)
test_loader = DataLoader(test_set, batch_size=1)
# Out:
# Take a look at sample from the dataset:
#      #  sepal length in cm  sepal width in cm  petal length in cm
# 0    1                 5.1                3.5                 1.4  \
# 1  101                 6.3                3.3                 6.0
# 2  110                 7.2                3.6                 6.1
# 3  145                 6.7                3.3                 5.7
# 4  115                 5.8                2.8                 5.1
#
#    petal width in cm       Iris_Type
# 0                0.2     Iris-setosa
# 1                2.5  Iris-virginica
# 2                2.5  Iris-virginica
# 3                2.5  Iris-virginica
# 4                2.4  Iris-virginica
#
#
# Our dataset is balanced and has the following values to predict:
# Iris_Type
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: count, dtype: int64
#
#
# Input values are:
#    sepal length in cm  sepal width in cm  petal length in cm
# 0                 5.1                3.5                 1.4  \
# 1                 6.3                3.3                 6.0
# 2                 7.2                3.6                 6.1
# 3                 6.7                3.3                 5.7
# 4                 5.8                2.8                 5.1
#
#    petal width in cm
# 0                0.2
# 1                2.5
# 2                2.5
# 3                2.5
# 4                2.4
#
#
# Output value is:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: IrisType_num, dtype: int64
#
#
# Input format:  torch.Size([150, 4]) torch.float32
# Output format:  torch.Size([150]) torch.int64

# %%
"""
model
"""

class IrisModel(nn.Module):
    def __init__(self, input_size, output_size):
        super(IrisModel, self).__init__()
        self.layer1 = nn.Linear(input_size, 24)
        self.layer2 = nn.Linear(24, 24)
        self.layer3 = nn.Linear(24, output_size)
    
    def forward(self, x):
        x1 = F.relu(self.layer1(x))
        x2 = F.relu(self.layer2(x1))
        x3 = self.layer3(x2)
        return x3
    
    def save(path):
        torch.save(self.state_dict(), path)
        
    # export for java calling
    def export(path):
        traced_script = torch.jit.trace(self, torch.zeros(input_size).float())

# %%
"""
init
"""

# select device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("The model will be running on", device, "device")

# create model
input_size = list(input.shape)[1]
output_size = len(labels)
model = IrisModel(input_size, output_size)
model.to(device)

# define loss-function
loss_fn = nn.CrossEntropyLoss(reduction='sum')

# define optimizer
LEARNING_RATE = 0.01
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
# Out:
# The model will be running on cpu device

# %%
def saveModel():
    torch.save(model.state_dict(), "iris-model.pth")
    # export model or java calling
    traced_script = torch.jit.trace(model, torch.tensor([1.0, 2.0, 3.0, 4.0]).float())
    traced_script.save("iris-model.out")

# %%
"""
train
"""

def train(num_epochs):
    accuracy_best = 0.0
    
    print("Begin training...")
    for epoch in range(1, num_epochs+1):
        running_train_loss = 0.0
        running_accuracy = 0.0
        running_val_loss = 0.0
        total = 0
        
        # train loop
        for data in train_loader:
            inputs, outputs = data
            pred_outputs = model(inputs)
            train_loss = loss_fn(pred_outputs, outputs)
            
            optimizer.zero_grad()
            train_loss.backward()
            optimizer.step()
            running_train_loss += train_loss.item()
            
        # calculate train loss
        train_loss_value = running_train_loss / len(train_loader)
        
        # verify loop
        with torch.no_grad():
            model.eval()
            for data in verify_loader:
                inputs, outputs = data
                print('[verify] output:', outputs)
                pred_outputs = model(inputs)
                print('[verify] pred_output:', pred_outputs)
                val_loss = loss_fn(pred_outputs, outputs)
                print('[verify] val_loss:', val_loss)
                
                # the lavel with the highest value will be our prediction
                dummy, pred = torch.max(pred_outputs, 1)
                print('[verify] torch.max:', dummy, pred)
                
                running_val_loss += val_loss.item()
                total += outputs.size(0)
                running_accuracy += (pred == outputs).sum().item()
        
        # calculate validation loss value
        val_loss_value = running_val_loss / len(verify_loader)
        
        # calculate accuracy as the number of correct predictions in the validation batch divided by the total number of predictions done
        accuracy = 100 * (running_accuracy / total)
        
        # save the model if the accuracy is the best
        if accuracy > accuracy_best:
            saveModel()
            accuracy_best = accuracy
        
        # print the statistics of the epoch
        print('Completed training batch', epoch, 'Training Loss is: %.4f' %train_loss_value, 'Validation Loss is: %.4f' %val_loss_value, 'Accuracy is: %d %%' %accuracy)

# %%
"""

"""
# Function to test the model
def test():
    # Load the model that we saved at the end of the training loop
    model = IrisModel(input_size, output_size)
    path = "iris-model.pth"
    model.load_state_dict(torch.load(path))
    
    running_accuracy = 0
    total = 0
    
    with torch.no_grad():
        for data in test_loader:
            inputs, outputs = data
            outputs = outputs.to(torch.float32)
            pred_outputs = model(inputs)
            _, pred = torch.max(pred_outputs, 1)
            total += outputs.size(0)
            running_accuracy += (pred == outputs).sum().item()
        accuracy = 100 * (running_accuracy / total)
        print('Accuracy of model based on the best set of', test_split, 'inputs is: %d %%' %accuracy)

# %%
# Optional: Function to test which species were easier to predict
def test_species():
    # Load the model that we saved at the end of the training loop
    model = IrisModel(input_size, output_size)
    path = "iris-model.pth"
    model.load_state_dict(torch.load(path))
    
    labels_length = len(labels)  # how many labels of Irises we have
    labels_correct = list(0. for i in range(labels_length))
    labels_total = list(0. for i in range(labels_length))
    
    with torch.no_grad():
        for data in test_loader:
            inputs, outputs = data
            pred_outputs = model(inputs)
            _, pred = torch.max(pred_outputs, 1)
            
            label_correct_running = (pred == outputs).squeeze();
            label = outputs[0]
            if label_correct_running.item():
                labels_correct[label] += 1
            labels_total[label] += 1
    
    label_list = list(labels.keys())
    for i in range(output_size):
        print('Accuracy to predict %5s: %2d %%' % (label_list[i], 100 * labels_correct[i] / labels_total[i]))

# %%
if __name__ == "__main__":
    num_epochs = 10
    train(num_epochs)
    print('Finished Training\n')
    test()
    test_species()
# Out:
# Begin training...
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.2245, -20.3975,   1.9669]])
# [verify] val_loss: tensor(9.5363e-05)
# [verify] torch.max: tensor([11.2245]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.5081, -22.5802,   2.0858]])
# [verify] val_loss: tensor(2.9802e-05)
# [verify] torch.max: tensor([12.5081]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-3.9310, -5.0323,  3.6782]])
# [verify] val_loss: tensor(0.0007)
# [verify] torch.max: tensor([3.6782]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.3692, -22.3780,   2.0978]])
# [verify] val_loss: tensor(3.4570e-05)
# [verify] torch.max: tensor([12.3692]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.2437, -20.4941,   2.0122]])
# [verify] val_loss: tensor(9.7866e-05)
# [verify] torch.max: tensor([11.2437]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.2705, -22.2454,   2.1120]])
# [verify] val_loss: tensor(3.8742e-05)
# [verify] torch.max: tensor([12.2705]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.4694, -20.7944,   1.9765]])
# [verify] val_loss: tensor(7.5337e-05)
# [verify] torch.max: tensor([11.4694]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.6869, -3.1934,  2.7885]])
# [verify] val_loss: tensor(0.0031)
# [verify] torch.max: tensor([2.7885]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.4338, -2.2654,  2.4154]])
# [verify] val_loss: tensor(0.0096)
# [verify] torch.max: tensor([2.4154]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.5025,   5.3052,  -0.6482]])
# [verify] val_loss: tensor(0.0026)
# [verify] torch.max: tensor([5.3052]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.9085, -23.3025,   2.1534]])
# [verify] val_loss: tensor(2.1338e-05)
# [verify] torch.max: tensor([12.9085]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-3.9735, -4.4429,  3.3450]])
# [verify] val_loss: tensor(0.0011)
# [verify] torch.max: tensor([3.3450]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.2484, -20.4666,   1.9860]])
# [verify] val_loss: tensor(9.4886e-05)
# [verify] torch.max: tensor([11.2484]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-2.2707, -7.1021,  4.5893]])
# [verify] val_loss: tensor(0.0011)
# [verify] torch.max: tensor([4.5893]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-9.8068,  3.6528, -0.1347]])
# [verify] val_loss: tensor(0.0224)
# [verify] torch.max: tensor([3.6528]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.8536, -21.5193,   2.0611]])
# [verify] val_loss: tensor(5.5908e-05)
# [verify] torch.max: tensor([11.8536]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.8839, -1.7339,  2.1695]])
# [verify] val_loss: tensor(0.0203)
# [verify] torch.max: tensor([2.1695]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-7.1853,  0.5011,  1.2354]])
# [verify] val_loss: tensor(0.3921)
# [verify] torch.max: tensor([1.2354]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.4775, -4.0915,  3.2215]])
# [verify] val_loss: tensor(0.0011)
# [verify] torch.max: tensor([3.2215]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-10.2257,   4.2437,  -0.4327]])
# [verify] val_loss: tensor(0.0093)
# [verify] torch.max: tensor([4.2437]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.7763, -2.7023,  2.7522]])
# [verify] val_loss: tensor(0.0045)
# [verify] torch.max: tensor([2.7522]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.4175, -20.6967,   1.9650]])
# [verify] val_loss: tensor(7.8437e-05)
# [verify] torch.max: tensor([11.4175]) tensor([0])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-10.6621,   4.4127,  -0.4489]])
# [verify] val_loss: tensor(0.0077)
# [verify] torch.max: tensor([4.4127]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.2663, -5.5536,  4.0410]])
# [verify] val_loss: tensor(0.0003)
# [verify] torch.max: tensor([4.0410]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-11.6643,   5.1269,  -0.7105]])
# [verify] val_loss: tensor(0.0029)
# [verify] torch.max: tensor([5.1269]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-13.1144,   5.9245,  -0.9365]])
# [verify] val_loss: tensor(0.0010)
# [verify] torch.max: tensor([5.9245]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.1181,   5.3572,  -0.7675]])
# [verify] val_loss: tensor(0.0022)
# [verify] torch.max: tensor([5.3572]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.7229, -3.1807,  2.9858]])
# [verify] val_loss: tensor(0.0023)
# [verify] torch.max: tensor([2.9858]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.8025, -23.1047,   2.1318]])
# [verify] val_loss: tensor(2.3246e-05)
# [verify] torch.max: tensor([12.8025]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 10.9538, -19.9357,   1.9399]])
# [verify] val_loss: tensor(0.0001)
# [verify] torch.max: tensor([10.9538]) tensor([0])
# Completed training batch 1 Training Loss is: 0.5113 Validation Loss is: 0.0162 Accuracy is: 100 %
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.2577, -20.5229,   1.9916]])
# [verify] val_loss: tensor(9.4528e-05)
# [verify] torch.max: tensor([11.2577]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.5447, -22.7178,   2.1124]])
# [verify] val_loss: tensor(2.9444e-05)
# [verify] torch.max: tensor([12.5447]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.0345, -5.0022,  3.6880]])
# [verify] val_loss: tensor(0.0006)
# [verify] torch.max: tensor([3.6880]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.4059, -22.5151,   2.1242]])
# [verify] val_loss: tensor(3.4212e-05)
# [verify] torch.max: tensor([12.4059]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.2753, -20.6180,   2.0374]])
# [verify] val_loss: tensor(9.7270e-05)
# [verify] torch.max: tensor([11.2753]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.3060, -22.3808,   2.1386]])
# [verify] val_loss: tensor(3.8385e-05)
# [verify] torch.max: tensor([12.3060]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.5027, -20.9210,   2.0013]])
# [verify] val_loss: tensor(7.4741e-05)
# [verify] torch.max: tensor([11.5027]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.7854, -3.1554,  2.7892]])
# [verify] val_loss: tensor(0.0031)
# [verify] torch.max: tensor([2.7892]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.5375, -2.2170,  2.4093]])
# [verify] val_loss: tensor(0.0101)
# [verify] torch.max: tensor([2.4093]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.6530,   5.4370,  -0.7159]])
# [verify] val_loss: tensor(0.0021)
# [verify] torch.max: tensor([5.4370]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.9465, -23.4444,   2.1806]])
# [verify] val_loss: tensor(2.1100e-05)
# [verify] torch.max: tensor([12.9465]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.0708, -4.4145,  3.3534]])
# [verify] val_loss: tensor(0.0010)
# [verify] torch.max: tensor([3.3534]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.2802, -20.5909,   2.0113]])
# [verify] val_loss: tensor(9.4290e-05)
# [verify] torch.max: tensor([11.2802]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-2.3614, -7.1015,  4.6152]])
# [verify] val_loss: tensor(0.0009)
# [verify] torch.max: tensor([4.6152]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-9.9295,  3.7860, -0.2060]])
# [verify] val_loss: tensor(0.0183)
# [verify] torch.max: tensor([3.7860]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.8879, -21.6505,   2.0871]])
# [verify] val_loss: tensor(5.5431e-05)
# [verify] torch.max: tensor([11.8879]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.9873, -1.6851,  2.1620]])
# [verify] val_loss: tensor(0.0214)
# [verify] torch.max: tensor([2.1620]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-7.2945,  0.5826,  1.2047]])
# [verify] val_loss: tensor(0.4298)
# [verify] torch.max: tensor([1.2047]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.5824, -4.0572,  3.2279]])
# [verify] val_loss: tensor(0.0011)
# [verify] torch.max: tensor([3.2279]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-10.3473,   4.3501,  -0.4874]])
# [verify] val_loss: tensor(0.0079)
# [verify] torch.max: tensor([4.3501]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.8926, -2.6454,  2.7444]])
# [verify] val_loss: tensor(0.0047)
# [verify] torch.max: tensor([2.7444]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.4522, -20.8251,   1.9897]])
# [verify] val_loss: tensor(7.7721e-05)
# [verify] torch.max: tensor([11.4522]) tensor([0])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-10.7891,   4.5240,  -0.5061]])
# [verify] val_loss: tensor(0.0065)
# [verify] torch.max: tensor([4.5240]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.3858, -5.5149,  4.0504]])
# [verify] val_loss: tensor(0.0003)
# [verify] torch.max: tensor([4.0504]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-11.7897,   5.2387,  -0.7696]])
# [verify] val_loss: tensor(0.0025)
# [verify] torch.max: tensor([5.2387]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-13.2437,   6.0412,  -1.0000]])
# [verify] val_loss: tensor(0.0009)
# [verify] torch.max: tensor([6.0412]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.2477,   5.4730,  -0.8289]])
# [verify] val_loss: tensor(0.0018)
# [verify] torch.max: tensor([5.4730]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.8410, -3.1275,  2.9813]])
# [verify] val_loss: tensor(0.0024)
# [verify] torch.max: tensor([2.9813]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.8404, -23.2458,   2.1586]])
# [verify] val_loss: tensor(2.3007e-05)
# [verify] torch.max: tensor([12.8404]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 10.9848, -20.0564,   1.9642]])
# [verify] val_loss: tensor(0.0001)
# [verify] torch.max: tensor([10.9848]) tensor([0])
# Completed training batch 2 Training Loss is: 0.5230 Validation Loss is: 0.0172 Accuracy is: 100 %
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.1427, -20.2463,   1.9043]])
# [verify] val_loss: tensor(9.7270e-05)
# [verify] torch.max: tensor([11.1427]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.4016, -22.3850,   2.0147]])
# [verify] val_loss: tensor(3.0875e-05)
# [verify] torch.max: tensor([12.4016]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.6414, -4.1347,  3.3156]])
# [verify] val_loss: tensor(0.0009)
# [verify] torch.max: tensor([3.3156]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.2835, -22.2176,   2.0286]])
# [verify] val_loss: tensor(3.5166e-05)
# [verify] torch.max: tensor([12.2835]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.1617, -20.3446,   1.9507]])
# [verify] val_loss: tensor(9.9892e-05)
# [verify] torch.max: tensor([11.1617]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.1826, -22.0832,   2.0441]])
# [verify] val_loss: tensor(3.9577e-05)
# [verify] torch.max: tensor([12.1826]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.3786, -20.6272,   1.9117]])
# [verify] val_loss: tensor(7.7364e-05)
# [verify] torch.max: tensor([11.3786]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.3606, -2.3253,  2.4284]])
# [verify] val_loss: tensor(0.0090)
# [verify] torch.max: tensor([2.4284]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.1340, -1.3508,  2.0300]])
# [verify] val_loss: tensor(0.0337)
# [verify] torch.max: tensor([2.0300]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-13.4142,   6.0231,  -0.9661]])
# [verify] val_loss: tensor(0.0009)
# [verify] torch.max: tensor([6.0231]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.8166, -23.1305,   2.0809]])
# [verify] val_loss: tensor(2.1696e-05)
# [verify] torch.max: tensor([12.8166]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.6477, -3.5883,  2.9978]])
# [verify] val_loss: tensor(0.0019)
# [verify] torch.max: tensor([2.9978]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.1468, -20.2847,   1.9235]])
# [verify] val_loss: tensor(9.8700e-05)
# [verify] torch.max: tensor([11.1468]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-2.8491, -6.4095,  4.2874]])
# [verify] val_loss: tensor(0.0008)
# [verify] torch.max: tensor([4.2874]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-10.5577,   4.5059,  -0.5710]])
# [verify] val_loss: tensor(0.0062)
# [verify] torch.max: tensor([4.5059]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.7674, -21.3607,   1.9955]])
# [verify] val_loss: tensor(5.6980e-05)
# [verify] torch.max: tensor([11.7674]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.5970, -0.7969,  1.7716]])
# [verify] val_loss: tensor(0.0741)
# [verify] torch.max: tensor([1.7716]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-7.8930,  1.5899,  0.7188]])
# [verify] val_loss: tensor(1.2207)
# [verify] torch.max: tensor([1.5899]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.1762, -3.1962,  2.8531]])
# [verify] val_loss: tensor(0.0027)
# [verify] torch.max: tensor([2.8531]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-10.9623,   4.8244,  -0.6902]])
# [verify] val_loss: tensor(0.0040)
# [verify] torch.max: tensor([4.8244]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.5461, -1.6967,  2.3296]])
# [verify] val_loss: tensor(0.0178)
# [verify] torch.max: tensor([2.3296]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.3332, -20.5400,   1.9005]])
# [verify] val_loss: tensor(8.0105e-05)
# [verify] torch.max: tensor([11.3332]) tensor([0])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-11.4423,   5.0264,  -0.7201]])
# [verify] val_loss: tensor(0.0032)
# [verify] torch.max: tensor([5.0264]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.0194, -4.5853,  3.6436]])
# [verify] val_loss: tensor(0.0004)
# [verify] torch.max: tensor([3.6436]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.3320,   5.6631,  -0.9563]])
# [verify] val_loss: tensor(0.0013)
# [verify] torch.max: tensor([5.6631]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-13.7939,   6.4616,  -1.1885]])
# [verify] val_loss: tensor(0.0005)
# [verify] torch.max: tensor([6.4616]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.8333,   5.9286,  -1.0287]])
# [verify] val_loss: tensor(0.0010)
# [verify] torch.max: tensor([5.9286]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.5175, -2.1475,  2.5540]])
# [verify] val_loss: tensor(0.0092)
# [verify] torch.max: tensor([2.5540]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.7118, -22.9345,   2.0595]])
# [verify] val_loss: tensor(2.3603e-05)
# [verify] torch.max: tensor([12.7118]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 10.8626, -19.7703,   1.8787]])
# [verify] val_loss: tensor(0.0001)
# [verify] torch.max: tensor([10.8626]) tensor([0])
# Completed training batch 3 Training Loss is: 0.4536 Validation Loss is: 0.0463 Accuracy is: 96 %
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.3932, -20.6819,   1.9408]])
# [verify] val_loss: tensor(7.8437e-05)
# [verify] torch.max: tensor([11.3932]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.6890, -22.8821,   2.0545]])
# [verify] val_loss: tensor(2.4080e-05)
# [verify] torch.max: tensor([12.6890]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.3407, -4.7248,  3.6022]])
# [verify] val_loss: tensor(0.0006)
# [verify] torch.max: tensor([3.6022]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.5560, -22.6911,   2.0680]])
# [verify] val_loss: tensor(2.7895e-05)
# [verify] torch.max: tensor([12.5560]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.4103, -20.7785,   1.9882]])
# [verify] val_loss: tensor(8.0940e-05)
# [verify] torch.max: tensor([11.4103]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.4534, -22.5545,   2.0839]])
# [verify] val_loss: tensor(3.1352e-05)
# [verify] torch.max: tensor([12.4534]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.6386, -21.0781,   1.9486]])
# [verify] val_loss: tensor(6.1868e-05)
# [verify] torch.max: tensor([11.6386]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.0797, -2.8704,  2.6896]])
# [verify] val_loss: tensor(0.0043)
# [verify] torch.max: tensor([2.6896]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.8459, -1.9052,  2.2932]])
# [verify] val_loss: tensor(0.0152)
# [verify] torch.max: tensor([2.2932]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-13.0884,   5.8250,  -0.9096]])
# [verify] val_loss: tensor(0.0012)
# [verify] torch.max: tensor([5.8250]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 13.1020, -23.6255,   2.1216]])
# [verify] val_loss: tensor(1.7047e-05)
# [verify] torch.max: tensor([13.1020]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.3622, -4.1474,  3.2686]])
# [verify] val_loss: tensor(0.0011)
# [verify] torch.max: tensor([3.2686]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.4078, -20.7381,   1.9610]])
# [verify] val_loss: tensor(7.8913e-05)
# [verify] torch.max: tensor([11.4078]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-2.6189, -6.9151,  4.5676]])
# [verify] val_loss: tensor(0.0008)
# [verify] torch.max: tensor([4.5676]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-10.2844,   4.2797,  -0.4780]])
# [verify] val_loss: tensor(0.0085)
# [verify] torch.max: tensor([4.2797]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.0302, -21.8181,   2.0342]])
# [verify] val_loss: tensor(4.5537e-05)
# [verify] torch.max: tensor([12.0302]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.3033, -1.3591,  2.0370]])
# [verify] val_loss: tensor(0.0332)
# [verify] torch.max: tensor([2.0370]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-7.6122,  1.0423,  0.9772]])
# [verify] val_loss: tensor(0.7263)
# [verify] torch.max: tensor([1.0423]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.8905, -3.7678,  3.1320]])
# [verify] val_loss: tensor(0.0013)
# [verify] torch.max: tensor([3.1320]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-10.6986,   4.6635,  -0.6440]])
# [verify] val_loss: tensor(0.0049)
# [verify] torch.max: tensor([4.6635]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.2313, -2.3031,  2.6180]])
# [verify] val_loss: tensor(0.0074)
# [verify] torch.max: tensor([2.6180]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.5899, -20.9851,   1.9371]])
# [verify] val_loss: tensor(6.4252e-05)
# [verify] torch.max: tensor([11.5899]) tensor([0])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-11.1605,   4.8549,  -0.6710]])
# [verify] val_loss: tensor(0.0040)
# [verify] torch.max: tensor([4.8549]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.7250, -5.2062,  3.9549]])
# [verify] val_loss: tensor(0.0003)
# [verify] torch.max: tensor([3.9549]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.1325,   5.5511,  -0.9307]])
# [verify] val_loss: tensor(0.0015)
# [verify] torch.max: tensor([5.5511]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-13.5891,   6.3578,  -1.1683]])
# [verify] val_loss: tensor(0.0005)
# [verify] torch.max: tensor([6.3578]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.6031,   5.7972,  -0.9964]])
# [verify] val_loss: tensor(0.0011)
# [verify] torch.max: tensor([5.7972]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.1899, -2.7796,  2.8554]])
# [verify] val_loss: tensor(0.0037)
# [verify] torch.max: tensor([2.8554]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.9951, -23.4256,   2.0998]])
# [verify] val_loss: tensor(1.8596e-05)
# [verify] torch.max: tensor([12.9951]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.1128, -20.2051,   1.9148]])
# [verify] val_loss: tensor(0.0001)
# [verify] torch.max: tensor([11.1128]) tensor([0])
# Completed training batch 4 Training Loss is: 0.8570 Validation Loss is: 0.0272 Accuracy is: 96 %
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.6136, -20.9016,   1.8327]])
# [verify] val_loss: tensor(5.6504e-05)
# [verify] torch.max: tensor([11.6136]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.9403, -23.1351,   1.9336]])
# [verify] val_loss: tensor(1.6570e-05)
# [verify] torch.max: tensor([12.9403]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.0608, -5.1810,  3.8078]])
# [verify] val_loss: tensor(0.0005)
# [verify] torch.max: tensor([3.8078]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.7959, -22.9282,   1.9487]])
# [verify] val_loss: tensor(1.9431e-05)
# [verify] torch.max: tensor([12.7959]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.6287, -20.9966,   1.8809]])
# [verify] val_loss: tensor(5.8411e-05)
# [verify] torch.max: tensor([11.6287]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.6916, -22.7911,   1.9663]])
# [verify] val_loss: tensor(2.1934e-05)
# [verify] torch.max: tensor([12.6916]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.8663, -21.3058,   1.8378]])
# [verify] val_loss: tensor(4.4106e-05)
# [verify] torch.max: tensor([11.8663]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.7855, -3.3246,  2.8877]])
# [verify] val_loss: tensor(0.0025)
# [verify] torch.max: tensor([2.8877]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.5435, -2.3719,  2.4969]])
# [verify] val_loss: tensor(0.0080)
# [verify] torch.max: tensor([2.4969]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.7185,   5.5906,  -0.8335]])
# [verify] val_loss: tensor(0.0016)
# [verify] torch.max: tensor([5.5906]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 13.3525, -23.8732,   1.9970]])
# [verify] val_loss: tensor(1.1682e-05)
# [verify] torch.max: tensor([13.3525]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.0669, -4.6041,  3.4677]])
# [verify] val_loss: tensor(0.0008)
# [verify] torch.max: tensor([3.4677]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.6360, -20.9711,   1.8536]])
# [verify] val_loss: tensor(5.6384e-05)
# [verify] torch.max: tensor([11.6360]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-2.3815, -7.3039,  4.7609]])
# [verify] val_loss: tensor(0.0008)
# [verify] torch.max: tensor([4.7609]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-9.9621,  3.8199, -0.2589]])
# [verify] val_loss: tensor(0.0168)
# [verify] torch.max: tensor([3.8199]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.2613, -22.0482,   1.9205]])
# [verify] val_loss: tensor(3.2305e-05)
# [verify] torch.max: tensor([12.2613]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.9937, -1.8373,  2.2460]])
# [verify] val_loss: tensor(0.0170)
# [verify] torch.max: tensor([2.2460]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-7.3072,  0.5518,  1.1979]])
# [verify] val_loss: tensor(0.4215)
# [verify] torch.max: tensor([1.1979]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.6135, -4.2225,  3.3380]])
# [verify] val_loss: tensor(0.0009)
# [verify] torch.max: tensor([3.3380]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-10.3956,   4.4710,  -0.5813]])
# [verify] val_loss: tensor(0.0064)
# [verify] torch.max: tensor([4.4710]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.9000, -2.8134,  2.8403]])
# [verify] val_loss: tensor(0.0037)
# [verify] torch.max: tensor([2.8403]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.8158, -21.2104,   1.8265]])
# [verify] val_loss: tensor(4.5895e-05)
# [verify] torch.max: tensor([11.8158]) tensor([0])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-10.8377,   4.6507,  -0.6050]])
# [verify] val_loss: tensor(0.0052)
# [verify] torch.max: tensor([4.6507]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.4210, -5.7038,  4.1797]])
# [verify] val_loss: tensor(0.0002)
# [verify] torch.max: tensor([4.1797]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-11.8567,   5.3773,  -0.8745]])
# [verify] val_loss: tensor(0.0019)
# [verify] torch.max: tensor([5.3773]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-13.3183,   6.1934,  -1.1159]])
# [verify] val_loss: tensor(0.0007)
# [verify] torch.max: tensor([6.1934]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.3182,   5.6177,  -0.9381]])
# [verify] val_loss: tensor(0.0014)
# [verify] torch.max: tensor([5.6177]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.8466, -3.3082,  3.0856]])
# [verify] val_loss: tensor(0.0018)
# [verify] torch.max: tensor([3.0856]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 13.2439, -23.6713,   1.9759]])
# [verify] val_loss: tensor(1.2755e-05)
# [verify] torch.max: tensor([13.2439]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.3316, -20.4258,   1.8096]])
# [verify] val_loss: tensor(7.3192e-05)
# [verify] torch.max: tensor([11.3316]) tensor([0])
# Completed training batch 5 Training Loss is: 0.5282 Validation Loss is: 0.0164 Accuracy is: 100 %
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.4820, -20.6417,   1.7642]])
# [verify] val_loss: tensor(6.0199e-05)
# [verify] torch.max: tensor([11.4820]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.7805, -22.8239,   1.8570]])
# [verify] val_loss: tensor(1.8000e-05)
# [verify] torch.max: tensor([12.7805]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.4983, -4.4987,  3.4993]])
# [verify] val_loss: tensor(0.0007)
# [verify] torch.max: tensor([3.4993]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.6546, -22.6476,   1.8734]])
# [verify] val_loss: tensor(2.0742e-05)
# [verify] torch.max: tensor([12.6546]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.4982, -20.7392,   1.8129]])
# [verify] val_loss: tensor(6.2225e-05)
# [verify] torch.max: tensor([11.4982]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.5497, -22.5106,   1.8918]])
# [verify] val_loss: tensor(2.3484e-05)
# [verify] torch.max: tensor([12.5497]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.7258, -21.0303,   1.7676]])
# [verify] val_loss: tensor(4.7325e-05)
# [verify] torch.max: tensor([11.7258]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.2205, -2.6585,  2.5892]])
# [verify] val_loss: tensor(0.0056)
# [verify] torch.max: tensor([2.5892]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.9946, -1.6775,  2.1841]])
# [verify] val_loss: tensor(0.0211)
# [verify] torch.max: tensor([2.1841]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-13.2910,   6.0339,  -1.0254]])
# [verify] val_loss: tensor(0.0009)
# [verify] torch.max: tensor([6.0339]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 13.2030, -23.5769,   1.9184]])
# [verify] val_loss: tensor(1.2517e-05)
# [verify] torch.max: tensor([13.2030]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.5024, -3.9406,  3.1720]])
# [verify] val_loss: tensor(0.0013)
# [verify] torch.max: tensor([3.1720]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.4885, -20.6862,   1.7850]])
# [verify] val_loss: tensor(6.1033e-05)
# [verify] torch.max: tensor([11.4885]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-2.7524, -6.7401,  4.4851]])
# [verify] val_loss: tensor(0.0007)
# [verify] torch.max: tensor([4.4851]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-10.4432,   4.5068,  -0.6166]])
# [verify] val_loss: tensor(0.0059)
# [verify] torch.max: tensor([4.5068]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.1231, -21.7755,   1.8486]])
# [verify] val_loss: tensor(3.4451e-05)
# [verify] torch.max: tensor([12.1231]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.4532, -1.1027,  1.9068]])
# [verify] val_loss: tensor(0.0484)
# [verify] torch.max: tensor([1.9068]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-7.7582,  1.3535,  0.8038]])
# [verify] val_loss: tensor(1.0054)
# [verify] torch.max: tensor([1.3535]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.0489, -3.5407,  3.0282]])
# [verify] val_loss: tensor(0.0017)
# [verify] torch.max: tensor([3.0282]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-10.8562,   4.8281,  -0.7362]])
# [verify] val_loss: tensor(0.0038)
# [verify] torch.max: tensor([4.8281]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.3950, -2.0514,  2.4974]])
# [verify] val_loss: tensor(0.0107)
# [verify] torch.max: tensor([2.4974]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.6804, -20.9430,   1.7566]])
# [verify] val_loss: tensor(4.8994e-05)
# [verify] torch.max: tensor([11.6804]) tensor([0])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-11.3271,   5.0293,  -0.7687]])
# [verify] val_loss: tensor(0.0030)
# [verify] torch.max: tensor([5.0293]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.9039, -4.9505,  3.8391]])
# [verify] val_loss: tensor(0.0003)
# [verify] torch.max: tensor([3.8391]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.2632,   5.6969,  -1.0173]])
# [verify] val_loss: tensor(0.0012)
# [verify] torch.max: tensor([5.6969]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-13.7184,   6.5005,  -1.2565]])
# [verify] val_loss: tensor(0.0004)
# [verify] torch.max: tensor([6.5005]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.7514,   5.9568,  -1.0893]])
# [verify] val_loss: tensor(0.0009)
# [verify] torch.max: tensor([5.9568]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.3594, -2.5202,  2.7317]])
# [verify] val_loss: tensor(0.0053)
# [verify] torch.max: tensor([2.7317]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 13.0958, -23.3776,   1.8978]])
# [verify] val_loss: tensor(1.3709e-05)
# [verify] torch.max: tensor([13.0958]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.1943, -20.1582,   1.7427]])
# [verify] val_loss: tensor(7.8556e-05)
# [verify] torch.max: tensor([11.1943]) tensor([0])
# Completed training batch 6 Training Loss is: 0.3894 Validation Loss is: 0.0373 Accuracy is: 96 %
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.8274, -21.3977,   1.9222]])
# [verify] val_loss: tensor(4.9947e-05)
# [verify] torch.max: tensor([11.8274]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 13.1851, -23.6952,   2.0315]])
# [verify] val_loss: tensor(1.4305e-05)
# [verify] torch.max: tensor([13.1851]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-3.8414, -5.7232,  4.0955]])
# [verify] val_loss: tensor(0.0004)
# [verify] torch.max: tensor([4.0955]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 13.0281, -23.4672,   2.0457]])
# [verify] val_loss: tensor(1.7047e-05)
# [verify] torch.max: tensor([13.0281]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.8401, -21.4912,   1.9719]])
# [verify] val_loss: tensor(5.1855e-05)
# [verify] torch.max: tensor([11.8401]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.9220, -23.3275,   2.0636]])
# [verify] val_loss: tensor(1.9193e-05)
# [verify] torch.max: tensor([12.9220]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.0876, -21.8162,   1.9286]])
# [verify] val_loss: tensor(3.8742e-05)
# [verify] torch.max: tensor([12.0876]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.5499, -3.8425,  3.1482]])
# [verify] val_loss: tensor(0.0014)
# [verify] torch.max: tensor([3.1482]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.3040, -2.8910,  2.7544]])
# [verify] val_loss: tensor(0.0038)
# [verify] torch.max: tensor([2.7544]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.4577,   5.4428,  -0.8051]])
# [verify] val_loss: tensor(0.0019)
# [verify] torch.max: tensor([5.4428]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 13.5953, -24.4350,   2.0975]])
# [verify] val_loss: tensor(1.0133e-05)
# [verify] torch.max: tensor([13.5953]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-3.8577, -5.1182,  3.7393]])
# [verify] val_loss: tensor(0.0006)
# [verify] torch.max: tensor([3.7393]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.8584, -21.4831,   1.9447]])
# [verify] val_loss: tensor(4.9471e-05)
# [verify] torch.max: tensor([11.8584]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-2.1929, -7.8054,  5.0565]])
# [verify] val_loss: tensor(0.0007)
# [verify] torch.max: tensor([5.0565]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-9.6995,  3.2860, -0.0143]])
# [verify] val_loss: tensor(0.0362)
# [verify] torch.max: tensor([3.2860]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.4850, -22.5689,   2.0150]])
# [verify] val_loss: tensor(2.8371e-05)
# [verify] torch.max: tensor([12.4850]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.7488, -2.3626,  2.5044]])
# [verify] val_loss: tensor(0.0079)
# [verify] torch.max: tensor([2.5044]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-7.0724,  0.0501,  1.4399]])
# [verify] val_loss: tensor(0.2226)
# [verify] torch.max: tensor([1.4399]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.3951, -4.7546,  3.6171]])
# [verify] val_loss: tensor(0.0006)
# [verify] torch.max: tensor([3.6171]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-10.1802,   4.3473,  -0.5563]])
# [verify] val_loss: tensor(0.0074)
# [verify] torch.max: tensor([4.3473]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.6387, -3.3806,  3.1224]])
# [verify] val_loss: tensor(0.0017)
# [verify] torch.max: tensor([3.1224]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.0353, -21.7168,   1.9167]])
# [verify] val_loss: tensor(4.0292e-05)
# [verify] torch.max: tensor([12.0353]) tensor([0])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-10.5999,   4.4360,  -0.5477]])
# [verify] val_loss: tensor(0.0068)
# [verify] torch.max: tensor([4.4360]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.1815, -6.2965,  4.4942]])
# [verify] val_loss: tensor(0.0002)
# [verify] torch.max: tensor([4.4942]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-11.6842,   5.2902,  -0.8672]])
# [verify] val_loss: tensor(0.0021)
# [verify] torch.max: tensor([5.2902]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-13.1588,   6.1242,  -1.1190]])
# [verify] val_loss: tensor(0.0007)
# [verify] torch.max: tensor([6.1242]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.1407,   5.5285,  -0.9312]])
# [verify] val_loss: tensor(0.0016)
# [verify] torch.max: tensor([5.5285]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.5751, -3.9007,  3.3817]])
# [verify] val_loss: tensor(0.0008)
# [verify] torch.max: tensor([3.3817]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 13.4850, -24.2287,   2.0753]])
# [verify] val_loss: tensor(1.1086e-05)
# [verify] torch.max: tensor([13.4850]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.5445, -20.9179,   1.8979]])
# [verify] val_loss: tensor(6.4609e-05)
# [verify] torch.max: tensor([11.5445]) tensor([0])
# Completed training batch 7 Training Loss is: 0.4801 Validation Loss is: 0.0099 Accuracy is: 100 %
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.4957, -20.5599,   1.6646]])
# [verify] val_loss: tensor(5.3762e-05)
# [verify] torch.max: tensor([11.4957]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.7834, -22.7124,   1.7457]])
# [verify] val_loss: tensor(1.6093e-05)
# [verify] torch.max: tensor([12.7834]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.9438, -3.9003,  3.2474]])
# [verify] val_loss: tensor(0.0011)
# [verify] torch.max: tensor([3.2474]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.6721, -22.5616,   1.7641]])
# [verify] val_loss: tensor(1.8358e-05)
# [verify] torch.max: tensor([12.6721]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.5119, -20.6594,   1.7145]])
# [verify] val_loss: tensor(5.5550e-05)
# [verify] torch.max: tensor([11.5119]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.5651, -22.4235,   1.7841]])
# [verify] val_loss: tensor(2.0742e-05)
# [verify] torch.max: tensor([12.5651]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.7342, -20.9372,   1.6654]])
# [verify] val_loss: tensor(4.2438e-05)
# [verify] torch.max: tensor([11.7342]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.6528, -2.0703,  2.3366]])
# [verify] val_loss: tensor(0.0125)
# [verify] torch.max: tensor([2.3366]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.4438, -1.0253,  1.8898]])
# [verify] val_loss: tensor(0.0530)
# [verify] torch.max: tensor([1.8898]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-13.8890,   6.5201,  -1.2541]])
# [verify] val_loss: tensor(0.0004)
# [verify] torch.max: tensor([6.5201]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 13.2191, -23.4837,   1.8043]])
# [verify] val_loss: tensor(1.1086e-05)
# [verify] torch.max: tensor([13.2191]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.9340, -3.3638,  2.9297]])
# [verify] val_loss: tensor(0.0022)
# [verify] torch.max: tensor([2.9297]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.4876, -20.5823,   1.6859]])
# [verify] val_loss: tensor(5.5312e-05)
# [verify] torch.max: tensor([11.4876]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-3.1176, -6.2786,  4.2792]])
# [verify] val_loss: tensor(0.0006)
# [verify] torch.max: tensor([4.2792]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-10.9332,   4.9008,  -0.7991]])
# [verify] val_loss: tensor(0.0033)
# [verify] torch.max: tensor([4.9008]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.1373, -21.6901,   1.7443]])
# [verify] val_loss: tensor(3.0636e-05)
# [verify] torch.max: tensor([12.1373]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.9089, -0.3654,  1.5511]])
# [verify] val_loss: tensor(0.1374)
# [verify] torch.max: tensor([1.5511]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-8.1993,  2.0688,  0.4509]])
# [verify] val_loss: tensor(1.7989)
# [verify] torch.max: tensor([2.0688]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.4814, -2.9462,  2.7716]])
# [verify] val_loss: tensor(0.0035)
# [verify] torch.max: tensor([2.7716]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-11.3312,   5.2155,  -0.9189]])
# [verify] val_loss: tensor(0.0022)
# [verify] torch.max: tensor([5.2155]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.8893, -1.3686,  2.2002]])
# [verify] val_loss: tensor(0.0279)
# [verify] torch.max: tensor([2.2002]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.6933, -20.8572,   1.6546]])
# [verify] val_loss: tensor(4.3630e-05)
# [verify] torch.max: tensor([11.6933]) tensor([0])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-11.8371,   5.4429,  -0.9627]])
# [verify] val_loss: tensor(0.0017)
# [verify] torch.max: tensor([5.4429]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.3828, -4.2988,  3.5620]])
# [verify] val_loss: tensor(0.0005)
# [verify] torch.max: tensor([3.5620]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.6503,   6.0168,  -1.1774]])
# [verify] val_loss: tensor(0.0008)
# [verify] torch.max: tensor([6.0168]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-14.1619,   6.8651,  -1.4396]])
# [verify] val_loss: tensor(0.0002)
# [verify] torch.max: tensor([6.8651]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-13.1665,   6.2986,  -1.2597]])
# [verify] val_loss: tensor(0.0005)
# [verify] torch.max: tensor([6.2986]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.8701, -1.8183,  2.4279]])
# [verify] val_loss: tensor(0.0143)
# [verify] torch.max: tensor([2.4279]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 13.1122, -23.2853,   1.7843]])
# [verify] val_loss: tensor(1.2040e-05)
# [verify] torch.max: tensor([13.1122]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.1994, -20.0657,   1.6457]])
# [verify] val_loss: tensor(7.0927e-05)
# [verify] torch.max: tensor([11.1994]) tensor([0])
# Completed training batch 8 Training Loss is: 0.4841 Validation Loss is: 0.0687 Accuracy is: 96 %
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.0955, -21.7882,   1.8757]])
# [verify] val_loss: tensor(3.6477e-05)
# [verify] torch.max: tensor([12.0955]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 13.4894, -24.1376,   1.9787]])
# [verify] val_loss: tensor(1.0014e-05)
# [verify] torch.max: tensor([13.4894]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-3.6081, -6.2349,  4.3710]])
# [verify] val_loss: tensor(0.0004)
# [verify] torch.max: tensor([4.3710]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 13.3201, -23.8922,   1.9947]])
# [verify] val_loss: tensor(1.2040e-05)
# [verify] torch.max: tensor([13.3201]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.1079, -21.8851,   1.9279]])
# [verify] val_loss: tensor(3.7908e-05)
# [verify] torch.max: tensor([12.1079]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 13.2125, -23.7530,   2.0145]])
# [verify] val_loss: tensor(1.3709e-05)
# [verify] torch.max: tensor([13.2125]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.3648, -22.2188,   1.8802]])
# [verify] val_loss: tensor(2.8014e-05)
# [verify] torch.max: tensor([12.3648]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.2901, -4.3588,  3.3998]])
# [verify] val_loss: tensor(0.0009)
# [verify] torch.max: tensor([3.3998]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.0384, -3.4140,  3.0071]])
# [verify] val_loss: tensor(0.0019)
# [verify] torch.max: tensor([3.0071]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.1466,   5.1677,  -0.7126]])
# [verify] val_loss: tensor(0.0028)
# [verify] torch.max: tensor([5.1677]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 13.9004, -24.8791,   2.0440]])
# [verify] val_loss: tensor(7.1525e-06)
# [verify] torch.max: tensor([13.9004]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-3.6249, -5.6228,  3.9971]])
# [verify] val_loss: tensor(0.0006)
# [verify] torch.max: tensor([3.9971]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.1355, -21.8899,   1.8996]])
# [verify] val_loss: tensor(3.5881e-05)
# [verify] torch.max: tensor([12.1355]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-1.9848, -8.2818,  5.3253]])
# [verify] val_loss: tensor(0.0007)
# [verify] torch.max: tensor([5.3253]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-9.4001,  2.6942,  0.2655]])
# [verify] val_loss: tensor(0.0845)
# [verify] torch.max: tensor([2.6942]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.7668, -22.9814,   1.9674]])
# [verify] val_loss: tensor(2.0385e-05)
# [verify] torch.max: tensor([12.7668]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.4827, -2.8855,  2.7560]])
# [verify] val_loss: tensor(0.0038)
# [verify] torch.max: tensor([2.7560]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.7979, -0.5057,  1.7096]])
# [verify] val_loss: tensor(0.1037)
# [verify] torch.max: tensor([1.7096]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-4.1519, -5.2790,  3.8822]])
# [verify] val_loss: tensor(0.0004)
# [verify] torch.max: tensor([3.8822]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-9.9226,  4.0030, -0.4006]])
# [verify] val_loss: tensor(0.0122)
# [verify] torch.max: tensor([4.0030]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.3383, -3.9677,  3.4054]])
# [verify] val_loss: tensor(0.0008)
# [verify] torch.max: tensor([3.4054]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.3087, -22.1129,   1.8681]])
# [verify] val_loss: tensor(2.9206e-05)
# [verify] torch.max: tensor([12.3087]) tensor([0])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-10.3054,   3.8989,  -0.2914]])
# [verify] val_loss: tensor(0.0150)
# [verify] torch.max: tensor([3.8989]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-3.9244, -6.8588,  4.7977]])
# [verify] val_loss: tensor(0.0002)
# [verify] torch.max: tensor([4.7977]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-11.4624,   5.1502,  -0.8304]])
# [verify] val_loss: tensor(0.0025)
# [verify] torch.max: tensor([5.1502]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.9459,   5.9929,  -1.0875]])
# [verify] val_loss: tensor(0.0008)
# [verify] torch.max: tensor([5.9929]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-11.9271,   5.3963,  -0.8985]])
# [verify] val_loss: tensor(0.0018)
# [verify] torch.max: tensor([5.3963]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.3007, -4.4803,  3.6710]])
# [verify] val_loss: tensor(0.0004)
# [verify] torch.max: tensor([3.6710]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 13.7877, -24.6682,   2.0217]])
# [verify] val_loss: tensor(7.7486e-06)
# [verify] torch.max: tensor([13.7877]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.8115, -21.3080,   1.8529]])
# [verify] val_loss: tensor(4.7325e-05)
# [verify] torch.max: tensor([11.8115]) tensor([0])
# Completed training batch 9 Training Loss is: 0.5981 Validation Loss is: 0.0078 Accuracy is: 100 %
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.3917, -20.5099,   1.6543]])
# [verify] val_loss: tensor(5.9007e-05)
# [verify] torch.max: tensor([11.3917]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.6630, -22.6474,   1.7337]])
# [verify] val_loss: tensor(1.7881e-05)
# [verify] torch.max: tensor([12.6630]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.0357, -3.7923,  3.1959]])
# [verify] val_loss: tensor(0.0012)
# [verify] torch.max: tensor([3.1959]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.5594, -22.5090,   1.7527]])
# [verify] val_loss: tensor(2.0265e-05)
# [verify] torch.max: tensor([12.5594]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.4095, -20.6155,   1.7062]])
# [verify] val_loss: tensor(6.1033e-05)
# [verify] torch.max: tensor([11.4095]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.4532, -22.3733,   1.7742]])
# [verify] val_loss: tensor(2.3007e-05)
# [verify] torch.max: tensor([12.4532]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.6261, -20.8817,   1.6543]])
# [verify] val_loss: tensor(4.6729e-05)
# [verify] torch.max: tensor([11.6261]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.7404, -1.9617,  2.2840]])
# [verify] val_loss: tensor(0.0145)
# [verify] torch.max: tensor([2.2840]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.5334, -0.8797,  1.8105]])
# [verify] val_loss: tensor(0.0659)
# [verify] torch.max: tensor([1.8105]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-14.0083,   6.6204,  -1.3113]])
# [verify] val_loss: tensor(0.0004)
# [verify] torch.max: tensor([6.6204]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 13.1012, -23.4276,   1.7923]])
# [verify] val_loss: tensor(1.2278e-05)
# [verify] torch.max: tensor([13.1012]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.0241, -3.2563,  2.8785]])
# [verify] val_loss: tensor(0.0025)
# [verify] torch.max: tensor([2.8785]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.3780, -20.5257,   1.6771]])
# [verify] val_loss: tensor(6.1272e-05)
# [verify] torch.max: tensor([11.3780]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-3.2129, -6.1809,  4.2336]])
# [verify] val_loss: tensor(0.0006)
# [verify] torch.max: tensor([4.2336]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-11.0255,   4.9788,  -0.8438]])
# [verify] val_loss: tensor(0.0030)
# [verify] torch.max: tensor([4.9788]) tensor([1])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.0286, -21.6406,   1.7346]])
# [verify] val_loss: tensor(3.3855e-05)
# [verify] torch.max: tensor([12.0286]) tensor([0])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-7.0050, -0.2059,  1.4645]])
# [verify] val_loss: tensor(0.1726)
# [verify] torch.max: tensor([1.4645]) tensor([2])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-8.2644,  2.1752,  0.3881]])
# [verify] val_loss: tensor(1.9420)
# [verify] torch.max: tensor([2.1752]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.5841, -2.8235,  2.7147]])
# [verify] val_loss: tensor(0.0042)
# [verify] torch.max: tensor([2.7147]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-11.4133,   5.2864,  -0.9613]])
# [verify] val_loss: tensor(0.0019)
# [verify] torch.max: tensor([5.2864]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.9775, -1.2565,  2.1437]])
# [verify] val_loss: tensor(0.0329)
# [verify] torch.max: tensor([2.1437]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.5863, -20.8022,   1.6432]])
# [verify] val_loss: tensor(4.8040e-05)
# [verify] torch.max: tensor([11.5863]) tensor([0])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-11.9262,   5.5196,  -1.0081]])
# [verify] val_loss: tensor(0.0015)
# [verify] torch.max: tensor([5.5196]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-5.4898, -4.1761,  3.5053]])
# [verify] val_loss: tensor(0.0006)
# [verify] torch.max: tensor([3.5053]) tensor([2])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-12.7145,   6.0708,  -1.2139]])
# [verify] val_loss: tensor(0.0007)
# [verify] torch.max: tensor([6.0708]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-14.2486,   6.9349,  -1.4837]])
# [verify] val_loss: tensor(0.0002)
# [verify] torch.max: tensor([6.9349]) tensor([1])
# [verify] output: tensor([1])
# [verify] pred_output: tensor([[-13.2347,   6.3557,  -1.2980]])
# [verify] val_loss: tensor(0.0005)
# [verify] torch.max: tensor([6.3557]) tensor([1])
# [verify] output: tensor([2])
# [verify] pred_output: tensor([[-6.9672, -1.6954,  2.3672]])
# [verify] val_loss: tensor(0.0171)
# [verify] torch.max: tensor([2.3672]) tensor([2])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 12.9951, -23.2286,   1.7719]])
# [verify] val_loss: tensor(1.3351e-05)
# [verify] torch.max: tensor([12.9951]) tensor([0])
# [verify] output: tensor([0])
# [verify] pred_output: tensor([[ 11.0953, -20.0133,   1.6362]])
# [verify] val_loss: tensor(7.7960e-05)
# [verify] torch.max: tensor([11.0953]) tensor([0])
# Completed training batch 10 Training Loss is: 0.7042 Validation Loss is: 0.0754 Accuracy is: 96 %
# Finished Training
#
# Accuracy of model based on the best set of 45 inputs is: 95 %
# Accuracy to predict Iris-setosa: 100 %
# Accuracy to predict Iris-virginica: 94 %
# Accuracy to predict Iris-versicolor: 93 %
